# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
data = pd.read_csv("Data/03_Library Systembook.csv")

# %%
data
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# ..   ...                                       ...           ...
# 109  NaN                                       NaN           NaN
# 110  NaN                                       NaN           NaN
# 111  NaN                                       NaN           NaN
# 112  NaN                                       NaN           NaN
# 113  NaN                                       NaN           NaN
#
#     Book Returned Days allowed to borrow  Customer ID
# 0      25/02/2023                2 weeks          1.0
# 1      21/03/2023                2 weeks          2.0
# ...

# %%
#data = data.fillna("value", inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9924\1923804259.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'value' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data = data.fillna("value", inplace=True)

# %%
data.dtypes
# Out:
# Id                        float64
# Books                      object
# Book checkout              object
# Book Returned              object
# Days allowed to borrow     object
# Customer ID               float64
# dtype: object

# %%
data

# %%
data_cleaned = data.dropna(how="all")

# %%
data_cleaned
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        IT  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                              Animal Farm   "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East of Eden  "30/04/2023"
# ...

# %%
#data_cleaned2 = pd.to_datetime(data["Book checkout"],  format='%d/%m/%Y')

# %%
# Source - https://stackoverflow.com/a/64518809
# Posted by stunner.agk
# Retrieved 2026-05-05, License - CC BY-SA 4.0

try: 
    data["Book checkout"] = pd.to_datetime(data["Book checkout"]) 
except ValueError as e: 
    pass
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9924\3700573005.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["Book checkout"] = pd.to_datetime(data["Book checkout"])

# %%
data
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# ..   ...                                       ...           ...
# 109  NaN                                       NaN           NaN
# 110  NaN                                       NaN           NaN
# 111  NaN                                       NaN           NaN
# 112  NaN                                       NaN           NaN
# 113  NaN                                       NaN           NaN
#
#     Book Returned Days allowed to borrow  Customer ID
# 0      25/02/2023                2 weeks          1.0
# 1      21/03/2023                2 weeks          2.0
# ...

# %%
print(data.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 109     True
# 110     True
# 111     True
# 112     True
# 113     True
# Length: 114, dtype: bool

# %%
data_cleaned.to_csv("out2.csv")
